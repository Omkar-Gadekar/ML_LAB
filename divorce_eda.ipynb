# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("/content/drive/MyDrive/ML/divorce.csv")

# %%
df.head()
# Out:
#   divorce_date     dob_man education_man  income_man   dob_woman  \
# 0   2006-09-06  1975-12-18     Secondary      2000.0  1983-08-01
# 1   2008-01-02  1976-11-17  Professional      6000.0  1977-03-13
# 2   2011-01-02  1969-04-06   Preparatory      5000.0  1970-02-16
# 3   2011-01-02  1979-11-13     Secondary     12000.0  1981-05-13
# 4   2011-01-02  1982-09-20  Professional      6000.0  1988-01-30
#
#   education_woman  income_woman marriage_date  marriage_duration  num_kids
# 0       Secondary        1800.0    2000-06-26                5.0       1.0
# 1    Professional        6000.0    2001-09-02                7.0       NaN
# 2    Professional        5000.0    2000-02-02                2.0       2.0
# 3       Secondary       12000.0    2006-05-13                2.0       NaN
# 4    Professional       10000.0    2007-08-06                3.0       NaN

# %%
df.tail()
# Out:
#      divorce_date     dob_man education_man  income_man   dob_woman  \
# 2204   2006-10-31  1969-11-27  Professional      6000.0  1975-09-01
# 2205   2006-10-31  1970-09-17  Professional      6000.0  1977-07-22
# 2206   2011-10-31  1976-03-11  Professional      8000.0  1978-12-28
# 2207   2012-10-31  1977-10-29  Professional     12500.0  1978-12-01
# 2208   2013-12-31  1960-06-22  Professional     20000.0  1972-01-22
#
#      education_woman  income_woman marriage_date  marriage_duration  num_kids
# 2204    Professional       14000.0    2002-03-08                4.0       NaN
# 2205    Professional        6000.0    2002-03-22                4.0       NaN
# 2206    Professional        7000.0    2009-02-10                2.0       NaN
# 2207    Professional        6000.0    2008-10-25                3.0       NaN
# 2208    Professional       20000.0    2009-08-22                4.0       NaN

# %%
df.describe()
# Out:
#          income_man  income_woman  marriage_duration     num_kids
# count   2209.000000   2209.000000        2209.000000  1333.000000
# mean    7922.986410   6793.164545           9.606609     1.672918
# std     7693.796497   6562.928689           7.266696     0.732858
# min        3.000000      3.500000           1.000000     1.000000
# 25%     3600.000000   3000.000000           4.000000     1.000000
# 50%     6000.000000   5000.000000           8.000000     2.000000
# 75%    10000.000000   8000.000000          14.000000     2.000000
# max    80000.000000  90000.000000          32.000000     5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2209 entries, 0 to 2208
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   divorce_date       2209 non-null   object
#  1   dob_man            2209 non-null   object
#  2   education_man      2209 non-null   object
#  3   income_man         2209 non-null   float64
#  4   dob_woman          2209 non-null   object
#  5   education_woman    2209 non-null   object
#  6   income_woman       2209 non-null   float64
#  7   marriage_date      2209 non-null   object
#  8   marriage_duration  2209 non-null   float64
#  9   num_kids           1333 non-null   float64
# dtypes: float64(4), object(6)
# memory usage: 172.7+ KB

# %%
df.shape
# Out:
# (2209, 10)

# %%
df.isna().sum()
# Out:
# divorce_date           0
# dob_man                0
# education_man          0
# income_man             0
# dob_woman              0
# education_woman        0
# income_woman           0
# marriage_date          0
# marriage_duration      0
# num_kids             876
# dtype: int64

# %%
df.isna()
# Out:
#       divorce_date  dob_man  education_man  income_man  dob_woman  \
# 0            False    False          False       False      False
# 1            False    False          False       False      False
# 2            False    False          False       False      False
# 3            False    False          False       False      False
# 4            False    False          False       False      False
# ...            ...      ...            ...         ...        ...
# 2204         False    False          False       False      False
# 2205         False    False          False       False      False
# 2206         False    False          False       False      False
# 2207         False    False          False       False      False
# 2208         False    False          False       False      False
#
#       education_woman  income_woman  marriage_date  marriage_duration  \
# 0               False         False          False              False
# ...

# %%
df['education_man'].unique()
# Out:
# array(['Secondary', 'Professional', 'Preparatory', 'Primary', 'Other',
#        'None'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
lbl_encoder = LabelEncoder()
df['education_man']=lbl_encoder.fit_transform(df['education_man'])
df['education_woman']=lbl_encoder.fit_transform(df['education_woman'])

# %%
df=df.drop("dob_man",axis=1)

# %%
df.head()
# Out:
#   divorce_date  education_man  income_man   dob_woman  education_woman  \
# 0   2006-09-06              5      2000.0  1983-08-01                4
# 1   2008-01-02              4      6000.0  1977-03-13                3
# 2   2011-01-02              2      5000.0  1970-02-16                3
# 3   2011-01-02              5     12000.0  1981-05-13                4
# 4   2011-01-02              4      6000.0  1988-01-30                3
#
#    income_woman marriage_date  marriage_duration  num_kids
# 0        1800.0    2000-06-26                5.0       1.0
# 1        6000.0    2001-09-02                7.0       NaN
# 2        5000.0    2000-02-02                2.0       2.0
# 3       12000.0    2006-05-13                2.0       NaN
# 4       10000.0    2007-08-06                3.0       NaN

# %%
df=df.drop("dob_woman",axis=1)

# %%
df=df.drop("marriage_date",axis=1)

# %%
df=df.drop("divorce_date", axis=1)

# %%
df.head()
# Out:
#    education_man  income_man  education_woman  income_woman  \
# 0              5      2000.0                4        1800.0
# 1              4      6000.0                3        6000.0
# 2              2      5000.0                3        5000.0
# 3              5     12000.0                4       12000.0
# 4              4      6000.0                3       10000.0
#
#    marriage_duration  num_kids
# 0                5.0       1.0
# 1                7.0       NaN
# 2                2.0       2.0
# 3                2.0       NaN
# 4                3.0       NaN

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')

df['num_kids'] = imputer.fit_transform(df[['num_kids']]).ravel()

# %%
df.head()
# Out:
#    education_man  income_man  education_woman  income_woman  \
# 0              5      2000.0                4        1800.0
# 1              4      6000.0                3        6000.0
# 2              2      5000.0                3        5000.0
# 3              5     12000.0                4       12000.0
# 4              4      6000.0                3       10000.0
#
#    marriage_duration  num_kids
# 0                5.0       1.0
# 1                7.0       1.0
# 2                2.0       2.0
# 3                2.0       1.0
# 4                3.0       1.0

# %%
X = df.drop("marriage_duration", axis=1)
y = df['marriage_duration']

# %%
X.head()
# Out:
#    education_man  income_man  education_woman  income_woman  num_kids
# 0              5      2000.0                4        1800.0       1.0
# 1              4      6000.0                3        6000.0       1.0
# 2              2      5000.0                3        5000.0       2.0
# 3              5     12000.0                4       12000.0       1.0
# 4              4      6000.0                3       10000.0       1.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
print('X_Training Shape: ', X_train.shape)
print('X_Testing Shape: ', X_test.shape)
print('Y_Training Shape: ', y_train.shape)
print('Y_Testing Shape: ', y_test.shape)
# Out:
# X_Training Shape:  (1767, 5)
# X_Testing Shape:  (442, 5)
# Y_Training Shape:  (1767,)
# Y_Testing Shape:  (442,)
